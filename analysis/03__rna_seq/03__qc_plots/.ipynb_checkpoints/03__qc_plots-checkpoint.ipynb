# %% [markdown]
# # 03__qc_plots
#
# notebook to QC RNA-seq results and differentially expressed genes -- from Winona
#
# figures in this notebook:
# - Supplemental Figure S11A-C

# %%
suppressMessages(library("DESeq2"))
library(ggplot2)

# %% [markdown]
# ## 1. plot gene lengths in human & mouse for sig & not sig

# %%
gene_lengths <- readRDS('../../../misc/00__ensembl_orthologs/orth_gene_lengths.rds')
head(gene_lengths)
# Out:
#                                     human_length median_hESC mouse_length
# ENSG00000065135__ENSMUSG00000000001 9044         3380.5      3262
# ENSG00000093009__ENSMUSG00000000028 2072         1267.5      2143
# ENSG00000102098__ENSMUSG00000000037 4162          865.0      4847
# ENSG00000091583__ENSMUSG00000000049 1174            0.0      1190
# ENSG00000141562__ENSMUSG00000000056 3814         1955.0      4395
# ENSG00000105971__ENSMUSG00000000058 2953          112.5      2733
#                                     median_mESC
# ENSG00000065135__ENSMUSG00000000001 2667.0
# ENSG00000093009__ENSMUSG00000000028 1502.5
# ENSG00000102098__ENSMUSG00000000037   29.5
# ENSG00000091583__ENSMUSG00000000049    0.0
# ENSG00000141562__ENSMUSG00000000056  400.0
# ENSG00000105971__ENSMUSG00000000058    1.0

# %%
gene_lengths$median_hESC <- as.numeric(gene_lengths$median_hESC)
gene_lengths$median_mESC <- as.numeric(gene_lengths$median_mESC)

# %%
orth_tf_expr = read.table("../../../data/03__rna_seq/04__TF_expr/orth_TF_expression.txt", sep='\t', header=T)
head(orth_tf_expr)
# Out:
#   gene_id_human   gene_name_human mean_tpm_human gene_id_mouse
# 1 ENSG00000142611 PRDM16            55.60172     ENSMUSG00000039410
# 2 ENSG00000078900 TP73             117.89739     ENSMUSG00000029026
# 3 ENSG00000173673 HES3             272.20870     ENSMUSG00000028946
# 4 ENSG00000204859 ZBTB48          1251.43732     ENSMUSG00000028952
# 5 ENSG00000125945 ZNF436           136.43462     ENSMUSG00000051351
# 6 ENSG00000007968 E2F2             369.97795     ENSMUSG00000018983
#   gene_name_mouse mean_tpm_mouse AveExpr   logFC      adj.P.Val    sig
# 1 Prdm16          612.9533        2.510447  4.9643059 1.771139e-10 sig
# 2 Trp73           239.6740        2.530112  2.5529517 4.216300e-07 sig
# 3 Hes3              0.0000       -1.119951 -7.6113367 1.590728e-10 sig
# 4 Zbtb48          342.8041        4.430457 -0.3879873 5.686419e-02 not sig
# 5 Zfp46           177.6659        2.222969  1.8368876 4.656334e-06 sig
# 6 E2f2            168.2240        3.107385  0.3475096 2.100320e-01 not sig
#   neg_log_padj
# 1 9.7517473
# 2 6.3750685
# 3 9.7984041
# 4 1.2451612
# 5 5.3319559
# 6 0.6777146

# %%
nrow(orth_tf_expr)
# Out:
# [1] 661

# %%
de_genes <- as.vector(orth_tf_expr$gene_id_human[orth_tf_expr$sig == 'sig'])
length(de_genes)
# Out:
# [1] 428

# %%
ggplot(gene_lengths, aes(x=human_length, y = mouse_length)) + geom_point() +
       ylim(0,30000) + xlim(0,30000) + 
       geom_point(data = gene_lengths[gsub('_.*','',rownames(gene_lengths)) %in% de_genes,], color='red')
# Out:
# Warning message:
# “Removed 7 rows containing missing values (geom_point).”
# plot without title

# %%
ggsave("FigS11B.pdf")
# Out:
# Saving 6.67 x 6.67 in image
# Warning message:
# “Removed 7 rows containing missing values (geom_point).”

# %% [markdown]
# ## 2. plot normalization values across samples (from edgeR)

# %%
suppressMessages(library(edgeR))
suppressMessages(library(limma))

# %%
install.packages("statmod")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
suppressMessages(library(statmod))

# %%
library(RColorBrewer)

# %%
orth_cts_all <- read.csv("../../../data/03__rna_seq/02__orths/01__featurecounts/orths.counts.voom.txt", sep="\t", row.names="orth_id")
orth_cts_all <- as.matrix(orth_cts_all)

# %%
options(stringsAsFactors = F)
set.seed(123)

# %%
dge <- DGEList(counts = orth_cts_all)

# %%
dge <- calcNormFactors(dge)
dim(dge)
# Out:
# [1] 18898    12

# %%
cutoff <- 1
drop <- which(apply(cpm(dge), 1, max) < cutoff)
d <- dge[-drop,] 
dim(d) # number of genes left
# Out:
# [1] 14068    12

# %%
### Plot log(cpm) distribution of each sample ####
lcpm <- cpm(dge, log = T)
col <- brewer.pal(12, "Paired")
par(mar=c(8,8,4,2))
pdf("FigS11A.pdf")
boxplot(lcpm, las=2, col=col, main='')
title(main = 'Normalized data', ylab = 'log-cpm')
dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## 3. plot foldchanges of DE genes vs. housekeeping genes

# %%
tt <- read.csv("../../../data/03__rna_seq/03__DE/orth.voom.tt_table.with_interaction.txt", sep="\t", header=T)
head(tt)
# Out:
#                                     logFC     AveExpr  t         P.Value
# ENSG00000115112__ENSMUSG00000026380  7.148172 7.181576  52.48438 6.474120e-17
# ENSG00000188375__ENSMUSG00000016559  6.430191 5.983091  50.22426 1.164959e-16
# ENSG00000087303__ENSMUSG00000021806  5.482785 6.100495  45.30814 4.601763e-16
# ENSG00000035403__ENSMUSG00000021823 -4.477505 8.112172 -43.18138 8.732277e-16
# ENSG00000161960__ENSMUSG00000059796  8.172684 6.797219  44.21971 6.362871e-16
# ENSG00000099290__ENSMUSG00000024104  5.545706 5.316533  44.21651 6.369009e-16
#                                     adj.P.Val    B
# ENSG00000115112__ENSMUSG00000026380 1.738140e-13 28.49261
# ENSG00000188375__ENSMUSG00000016559 1.738140e-13 27.76637
# ENSG00000087303__ENSMUSG00000021806 2.811307e-13 26.78435
# ENSG00000035403__ENSMUSG00000021823 3.149889e-13 26.40572
# ENSG00000161960__ENSMUSG00000059796 2.852655e-13 26.36007
# ENSG00000099290__ENSMUSG00000024104 2.852655e-13 26.27937

# %%
housekeeping <- c('ENSG00000116459','ENSG00000102144','ENSG00000111640','ENSG00000166710','ENSG00000075624')
genes <- c(de_genes, housekeeping)

# %%
tt$human_gene <- gsub('__.*','', rownames(tt)) 
gene <- as.data.frame((tt[tt$human_gene %in% genes,c('logFC','human_gene')]))
all_genes <- gene

# %%
all_genes$status[all_genes$human_gene %in% housekeeping] <- 'housekeeping' 
all_genes$status[all_genes$human_gene %in% de_genes] <- 'differentially expressed TF'

# %%
all_genes$logFC <- as.numeric(abs(all_genes$logFC))

# %%
ggplot(all_genes, aes(x=reorder(status,human_gene),y = logFC,fill=status)) + geom_boxplot(outlier.shape = NA)  + 
  #geom_point(aes(fill=cell),color=all_genes$color) + 
  theme_bw() + scale_fill_manual(values = c('#E99675','#72B6A1')) +
  scale_color_manual(values = c('#E99675','#72B6A1')) +
  #geom_vline(xintercept=5.5, color="grey", size=1) +
  #scale_y_continuous(trans='log10') +
  theme(text = element_text(size = 18), axis.text = element_text(size = 20), legend.position = 'none') + 
  ylab('logFC')+ xlab('')+ylim(0,12)+
  theme(panel.grid.major = element_blank(),panel.grid.minor = element_blank())
# Out:
# Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”Warning message:
# “Removed 4 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
ggsave("FigS11C.pdf")
# Out:
# Saving 6.67 x 6.67 in image
# Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”Warning message in mean.default(X[[i]], ...):
# “argument is not numeric or logical: returning NA”Warning message:
# “Removed 4 rows containing non-finite values (stat_boxplot).”
