# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import math
import matplotlib.pyplot as plt
import numpy as np
import re
import seaborn as sns
import sys

from scipy.stats import spearmanr

# import utils
sys.path.append("../../../utils")
from plotting_utils import *

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
mpl.rcParams['figure.autolayout'] = False

# %% [markdown]
# ## variables

# %%
human_master_f = "../../../data/01__design/00__genome_list/hg19.master_list.txt.gz"
mouse_master_f = "../../../data/01__design/00__genome_list/mm9.master_list.txt.gz"

# %% [markdown]
# ## 1. import data

# %%
human_master = pd.read_table(human_master_f, sep="\t")
human_master.head()
# Out:
#   chr_tss_hg19  start_tss_hg19  end_tss_hg19  \
# 0         chr1          564588        564589
# 1         chr1          564645        564646
# 2         chr1          565269        565270
# 3         chr1          565480        565481
# 4         chr1          565523        565524
#
#                          name_tss_hg19  score_tss_hg19 strand_tss_hg19  \
# 0  ENSG00000225972.1,ENSG00000225630.1            2398               +
# 1  ENSG00000225972.1,ENSG00000225630.1             220               +
# 2  ENSG00000225972.1,ENSG00000225630.1             535               +
# 3  ENSG00000237973.1,ENSG00000225630.1             106               +
# 4  ENSG00000237973.1,ENSG00000225630.1            3594               +
#
#             cage_id_hg19  biotype_hg19  seq_orth  cage_orth     ...       \
# 0  chr1:564571..564600,+  multi-mapped     False      False     ...
# 1  chr1:564639..564649,+  multi-mapped     False      False     ...
# 2  chr1:565266..565278,+  multi-mapped     False      False     ...
# 3  chr1:565478..565483,+  multi-mapped     False      False     ...
# 4  chr1:565509..565541,+  multi-mapped     False      False     ...
#
#      score_peak_mm9       cage_id_mm9       biotype_mm9      stem_exp_mm9  \
# 0  no cage activity  no cage activity  no cage activity  no cage activity
# 1  no cage activity  no cage activity  no cage activity  no cage activity
# 2  no cage activity  no cage activity  no cage activity  no cage activity
# 3  no cage activity  no cage activity  no cage activity  no cage activity
# 4  no cage activity  no cage activity  no cage activity  no cage activity
#
#         avg_exp_mm9    har repeat_hg19 repeat_mm9 repeat_status remap_status
# 0  no cage activity  False         NaN        NaN    no repeats   remap fail
# 1  no cage activity  False         NaN        NaN    no repeats   remap fail
# 2  no cage activity  False         NaN        NaN    no repeats   remap fail
# 3  no cage activity  False         NaN        NaN    no repeats   remap fail
# 4  no cage activity  False         NaN        NaN    no repeats   remap fail
#
# [5 rows x 25 columns]

# %%
mouse_master = pd.read_table(mouse_master_f, sep="\t")
mouse_master.head()
# Out:
#   chr_tss_mm9  start_tss_mm9  end_tss_mm9          name_tss_mm9  \
# 0        chr1        3309585      3309586            unassigned
# 1        chr1        3367867      3367868  ENSMUSG00000104017.1
# 2        chr1        3479231      3479232            unassigned
# 3        chr1        3644977      3644978            unassigned
# 4        chr1        3657916      3657917            unassigned
#
#    score_tss_mm9 strand_tss_mm9              cage_id_mm9      biotype_mm9  \
# 0            153              -  chr1:3309585..3309588,-       unassigned
# 1            569              -  chr1:3367867..3367870,-  other_noncoding
# 2            163              -  chr1:3479230..3479234,-       unassigned
# 3            493              -  chr1:3644976..3644980,-       unassigned
# 4            904              -  chr1:3657915..3657919,-       unassigned
#
#    seq_orth  cage_orth     ...        score_peak_hg19      cage_id_hg19  \
# 0     False      False     ...       no cage activity  no cage activity
# 1     False      False     ...       no cage activity  no cage activity
# 2     False      False     ...       no cage activity  no cage activity
# 3      True      False     ...       no cage activity  no cage activity
# 4     False      False     ...       no cage activity  no cage activity
#
#        biotype_hg19     stem_exp_hg19      avg_exp_hg19    har repeat_mm9  \
# 0  no cage activity  no cage activity  no cage activity  False        NaN
# 1  no cage activity  no cage activity  no cage activity  False        NaN
# 2  no cage activity  no cage activity  no cage activity  False      Lx2A1
# 3  no cage activity  no cage activity  no cage activity  False        NaN
# 4  no cage activity  no cage activity  no cage activity  False    AT_rich
#
#   repeat_hg19 repeat_status remap_status
# 0         NaN    no repeats          NaN
# 1         NaN    no repeats          NaN
# 2         NaN        repeat          NaN
# 3         NaN    no repeats          NaN
# 4         NaN        repeat          NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 2. filter to seq orths only

# %%
human_master_filt = human_master[human_master["seq_orth"]]
len(human_master_filt)
# Out:
# 195110

# %%
mouse_master_filt = mouse_master[mouse_master["seq_orth"]]
len(mouse_master_filt)
# Out:
# 163131

# %% [markdown]
# ## 3. find TSS coords for human/mouse paired regions
# do it for both the "human" file (started from human) and the "mouse" file (started from mouse)

# %%
human_bed_hg19 = human_master_filt[["chr_tss_hg19", "start_tss_hg19", "end_tss_hg19", "cage_id_hg19",
                                    "score_tss_hg19", "strand_tss_hg19"]].drop_duplicates()
print(len(human_bed_hg19))
human_bed_hg19.head()
# Out:
# 193830
#    chr_tss_hg19  start_tss_hg19  end_tss_hg19           cage_id_hg19  \
# 35         chr1          869211        869212  chr1:869192..869225,+
# 36         chr1          869324        869325  chr1:869322..869329,+
# 48         chr1          894635        894636  chr1:894620..894659,-
# 49         chr1          895911        895912  chr1:895904..895925,-
# 50         chr1          896012        896013  chr1:895930..896033,+
#
#     score_tss_hg19 strand_tss_hg19
# 35             331               +
# 36             284               +
# 48          160511               -
# 49            1196               -
# 50           21903               +

# %%
human_bed_mm9 = human_master_filt[["chr_tss_mm9", "start_tss_mm9", "end_tss_mm9", "cage_id_hg19",
                                   "score_tss_hg19", "strand_tss_mm9"]].drop_duplicates()
print(len(human_bed_mm9))
human_bed_mm9.head()
# Out:
# 192046
#    chr_tss_mm9 start_tss_mm9 end_tss_mm9           cage_id_hg19  \
# 35        chr4     155629557   155629558  chr1:869192..869225,+
# 36        chr4     155629445   155629446  chr1:869322..869329,+
# 48        chr4     155610134   155610135  chr1:894620..894659,-
# 49        chr4     155608996   155608997  chr1:895904..895925,-
# 50        chr4     155608903   155608904  chr1:895930..896033,+
#
#     score_tss_hg19 strand_tss_mm9
# 35             331              -
# 36             284              -
# 48          160511              +
# 49            1196              +
# 50           21903              -

# %%
human_bed_mm9[human_bed_mm9["cage_id_hg19"] == "chr1:203273760..203273784,-"]
# Out:
#        chr_tss_mm9 start_tss_mm9 end_tss_mm9                 cage_id_hg19  \
# 330682        chr1     135976545   135976546  chr1:203273760..203273784,-
#
#         score_tss_hg19 strand_tss_mm9
# 330682             851              +

# %%
mouse_bed_mm9 = mouse_master_filt[["chr_tss_mm9", "start_tss_mm9", "end_tss_mm9", "cage_id_mm9",
                                    "score_tss_mm9", "strand_tss_mm9"]].drop_duplicates()
print(len(mouse_bed_mm9))
mouse_bed_mm9.head()
# Out:
# 162047
#   chr_tss_mm9  start_tss_mm9  end_tss_mm9              cage_id_mm9  \
# 3        chr1        3644977      3644978  chr1:3644976..3644980,-
# 5        chr1        3661803      3661804  chr1:3661752..3661814,-
# 6        chr1        3661874      3661875  chr1:3661851..3661889,-
# 7        chr1        3664691      3664692  chr1:3664689..3664693,+
# 9        chr1        4350322      4350323  chr1:4350318..4350327,-
#
#    score_tss_mm9 strand_tss_mm9
# 3            493              -
# 5           4638              -
# 6           2432              -
# 7            578              +
# 9            413              -

# %%
mouse_bed_hg19 = mouse_master_filt[["chr_tss_hg19", "start_tss_hg19", "end_tss_hg19", "cage_id_mm9",
                                    "score_tss_mm9", "strand_tss_hg19"]].drop_duplicates()
print(len(mouse_bed_hg19))
mouse_bed_hg19.head()
# Out:
# 159952
#   chr_tss_hg19 start_tss_hg19 end_tss_hg19              cage_id_mm9  \
# 3         chr8       56032920     56032921  chr1:3644976..3644980,-
# 5         chr8       56014691     56014692  chr1:3661752..3661814,-
# 6         chr8       56014587     56014588  chr1:3661851..3661889,-
# 7         chr8       56011954     56011955  chr1:3664689..3664693,+
# 9         chr8       55528655     55528656  chr1:4350318..4350327,-
#
#    score_tss_mm9 strand_tss_hg19
# 3            493               +
# 5           4638               +
# 6           2432               +
# 7            578               -
# 9            413               +

# %% [markdown]
# ## 4. group hg19/mm9 files together for bed intersect

# %%
human_bed_hg19["cage_id"] = "HUMAN_CAGE_ID__" + human_bed_hg19["cage_id_hg19"]
mouse_bed_hg19["cage_id"] = "MOUSE_CAGE_ID__" + mouse_bed_hg19["cage_id_mm9"]
human_bed_hg19["score"] = "HUMAN_SCORE__" + human_bed_hg19["score_tss_hg19"].astype(str)
mouse_bed_hg19["score"] = "MOUSE_SCORE__" + mouse_bed_hg19["score_tss_mm9"].astype(str)
human_bed_hg19.head()
# Out:
#    chr_tss_hg19  start_tss_hg19  end_tss_hg19           cage_id_hg19  \
# 35         chr1          869211        869212  chr1:869192..869225,+
# 36         chr1          869324        869325  chr1:869322..869329,+
# 48         chr1          894635        894636  chr1:894620..894659,-
# 49         chr1          895911        895912  chr1:895904..895925,-
# 50         chr1          896012        896013  chr1:895930..896033,+
#
#     score_tss_hg19 strand_tss_hg19                               cage_id  \
# 35             331               +  HUMAN_CAGE_ID__chr1:869192..869225,+
# 36             284               +  HUMAN_CAGE_ID__chr1:869322..869329,+
# 48          160511               -  HUMAN_CAGE_ID__chr1:894620..894659,-
# 49            1196               -  HUMAN_CAGE_ID__chr1:895904..895925,-
# 50           21903               +  HUMAN_CAGE_ID__chr1:895930..896033,+
#
#                   score
# 35     HUMAN_SCORE__331
# 36     HUMAN_SCORE__284
# 48  HUMAN_SCORE__160511
# 49    HUMAN_SCORE__1196
# 50   HUMAN_SCORE__21903

# %%
human_bed_mm9["cage_id"] = "HUMAN_CAGE_ID__" + human_bed_mm9["cage_id_hg19"]
mouse_bed_mm9["cage_id"] = "MOUSE_CAGE_ID__" + mouse_bed_mm9["cage_id_mm9"]
human_bed_mm9["score"] = "HUMAN_SCORE__" + human_bed_hg19["score_tss_hg19"].astype(str)
mouse_bed_mm9["score"] = "MOUSE_SCORE__" + mouse_bed_hg19["score_tss_mm9"].astype(str)
human_bed_mm9.head()
# Out:
#    chr_tss_mm9 start_tss_mm9 end_tss_mm9           cage_id_hg19  \
# 35        chr4     155629557   155629558  chr1:869192..869225,+
# 36        chr4     155629445   155629446  chr1:869322..869329,+
# 48        chr4     155610134   155610135  chr1:894620..894659,-
# 49        chr4     155608996   155608997  chr1:895904..895925,-
# 50        chr4     155608903   155608904  chr1:895930..896033,+
#
#     score_tss_hg19 strand_tss_mm9                               cage_id  \
# 35             331              -  HUMAN_CAGE_ID__chr1:869192..869225,+
# 36             284              -  HUMAN_CAGE_ID__chr1:869322..869329,+
# 48          160511              +  HUMAN_CAGE_ID__chr1:894620..894659,-
# 49            1196              +  HUMAN_CAGE_ID__chr1:895904..895925,-
# 50           21903              -  HUMAN_CAGE_ID__chr1:895930..896033,+
#
#                   score
# 35     HUMAN_SCORE__331
# 36     HUMAN_SCORE__284
# 48  HUMAN_SCORE__160511
# 49    HUMAN_SCORE__1196
# 50   HUMAN_SCORE__21903

# %%
hg19_bed = human_bed_hg19[["chr_tss_hg19", "start_tss_hg19", "end_tss_hg19", "cage_id", "score", "strand_tss_hg19"]]
hg19_bed = hg19_bed.append(mouse_bed_hg19[["chr_tss_hg19", "start_tss_hg19", "end_tss_hg19", "cage_id", "score", "strand_tss_hg19"]])
hg19_bed.drop_duplicates(inplace=True)
print(len(hg19_bed))
hg19_bed.sample(5)
# Out:
# 353782
#        chr_tss_hg19 start_tss_hg19 end_tss_hg19  \
# 42253         chr10       79601936     79601937
# 62436         chr15       59904093     59904094
# 238011         chr8       17956477     17956478
# 159641         chr6       46666709     46666710
# 205373        chr10       29948332     29948333
#
#                                           cage_id              score  \
# 42253   MOUSE_CAGE_ID__chr14:24995888..24995889,-    MOUSE_SCORE__22
# 62436   HUMAN_CAGE_ID__chr15:59904077..59904099,+  HUMAN_SCORE__1828
# 238011      MOUSE_CAGE_ID__chr8:42470128-42470210     MOUSE_SCORE__4
# 159641   HUMAN_CAGE_ID__chr6:46666704..46666713,-   HUMAN_SCORE__170
# 205373     HUMAN_CAGE_ID__chr10:29948331-29948643     HUMAN_SCORE__4
#
#        strand_tss_hg19
# 42253                -
# 62436                +
# 238011               +
# 159641               -
# 205373               -

# %%
mm9_bed = human_bed_mm9[["chr_tss_mm9", "start_tss_mm9", "end_tss_mm9", "cage_id", "score", "strand_tss_mm9"]]
mm9_bed = mm9_bed.append(mouse_bed_mm9[["chr_tss_mm9", "start_tss_mm9", "end_tss_mm9", "cage_id", "score", "strand_tss_mm9"]])
mm9_bed.drop_duplicates(inplace=True)
print(len(mm9_bed))
mm9_bed.sample(5)
# Out:
# 354093
#        chr_tss_mm9 start_tss_mm9 end_tss_mm9  \
# 38691         chr6     124699533   124699534
# 74469        chr19      34319511    34319512
# 97763        chr12       8016112     8016113
# 273848        chr2      93052823    93052824
# 95071         chr3     117337160   117337161
#
#                                            cage_id              score  \
# 38691      HUMAN_CAGE_ID__chr12:7043414..7043430,+  HUMAN_SCORE__7918
# 74469    MOUSE_CAGE_ID__chr19:34319481..34319529,-  MOUSE_SCORE__2563
# 97763     HUMAN_CAGE_ID__chr2:21231944..21231959,-   HUMAN_SCORE__845
# 273848      HUMAN_CAGE_ID__chr11:44938363-44938586     HUMAN_SCORE__7
# 95071   MOUSE_CAGE_ID__chr3:117337158..117337161,+   MOUSE_SCORE__189
#
#        strand_tss_mm9
# 38691               -
# 74469               -
# 97763               +
# 273848              -
# 95071               +

# %% [markdown]
# ## 5. add buffer of +/- 50 bp

# %%
hg19_bed["start_tss_hg19"] = hg19_bed["start_tss_hg19"].astype(int) - 49
hg19_bed["end_tss_hg19"] = hg19_bed["end_tss_hg19"].astype(int) + 50
hg19_bed["score"] = 0
hg19_bed.head()
# Out:
#    chr_tss_hg19  start_tss_hg19  end_tss_hg19  \
# 35         chr1          869162        869262
# 36         chr1          869275        869375
# 48         chr1          894586        894686
# 49         chr1          895862        895962
# 50         chr1          895963        896063
#
#                                  cage_id  score strand_tss_hg19
# 35  HUMAN_CAGE_ID__chr1:869192..869225,+      0               +
# 36  HUMAN_CAGE_ID__chr1:869322..869329,+      0               +
# 48  HUMAN_CAGE_ID__chr1:894620..894659,-      0               -
# 49  HUMAN_CAGE_ID__chr1:895904..895925,-      0               -
# 50  HUMAN_CAGE_ID__chr1:895930..896033,+      0               +

# %%
mm9_bed["start_tss_mm9"] = mm9_bed["start_tss_mm9"].astype(int) - 49
mm9_bed["end_tss_mm9"] = mm9_bed["end_tss_mm9"].astype(int) + 50
mm9_bed["score"] = 0
mm9_bed.head()
# Out:
#    chr_tss_mm9  start_tss_mm9  end_tss_mm9  \
# 35        chr4      155629508    155629608
# 36        chr4      155629396    155629496
# 48        chr4      155610085    155610185
# 49        chr4      155608947    155609047
# 50        chr4      155608854    155608954
#
#                                  cage_id  score strand_tss_mm9
# 35  HUMAN_CAGE_ID__chr1:869192..869225,+      0              -
# 36  HUMAN_CAGE_ID__chr1:869322..869329,+      0              -
# 48  HUMAN_CAGE_ID__chr1:894620..894659,-      0              +
# 49  HUMAN_CAGE_ID__chr1:895904..895925,-      0              +
# 50  HUMAN_CAGE_ID__chr1:895930..896033,+      0              -

# %% [markdown]
# ## 6. write files

# %%
hg19_bed.to_csv("../../../data/01__design/00__genome_list/hg19_master.50buff.bed", header=False, index=False, sep="\t")
mm9_bed.to_csv("../../../data/01__design/00__genome_list/mm9_master.50buff.bed", header=False, index=False, sep="\t")
